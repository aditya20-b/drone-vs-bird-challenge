# %%
import ultralytics
from ultralytics import YOLO

# %%
from ultralytics.data.converter import convert_coco

convert_coco('combined_annotations.json', save_dir='coco_to_yolo')
# Out:
# COCO data converted successfully.
# Results saved to /Users/aditya/Documents/Github/drone-vs-bird-challenge/coco_to_yolo

# %%
import json

# Path to COCO JSON file
coco_file = "combined_annotations.json"

# Load COCO JSON
with open(coco_file, "r") as f:
    coco_data = json.load(f)

# Check for annotations
images = {img["id"]: img["file_name"] for img in coco_data["images"]}
annotations = coco_data["annotations"]

for ann in annotations:
    image_id = ann["image_id"]
    if image_id not in images:
        # print(f"Annotation found for image {images[image_id]}: {ann}")
    # else:
    
        print(f"Invalid annotation with image_id: {image_id}")

# %%
import json
import os

def validate_coco_annotations(coco_file):
    with open(coco_file, "r") as f:
        coco_data = json.load(f)

    # Validate sections
    if not all(key in coco_data for key in ["images", "annotations", "categories"]):
        print("Error: Missing one or more required sections: 'images', 'annotations', 'categories'.")
        return False

    images = {img["id"]: img for img in coco_data["images"]}
    categories = {cat["id"]: cat["name"] for cat in coco_data["categories"]}
    annotations = coco_data["annotations"]

    print(f"Total Images: {len(images)}")
    print(f"Total Annotations: {len(annotations)}")
    print(f"Total Categories: {len(categories)}")

    # Track validation issues
    issues = []

    # Check if images have valid data
    for img_id, img in images.items():
        if "file_name" not in img or "width" not in img or "height" not in img:
            issues.append(f"Image ID {img_id} is missing required fields (file_name, width, height).")

    # Check annotations
    for ann in annotations:
        image_id = ann.get("image_id")
        category_id = ann.get("category_id")
        bbox = ann.get("bbox")

        # Validate image_id
        if image_id not in images:
            issues.append(f"Annotation ID {ann['id']} references invalid image_id {image_id}.")

        # Validate category_id
        if category_id not in categories:
            issues.append(f"Annotation ID {ann['id']} references invalid category_id {category_id}.")

        # Validate bbox
        if bbox:
            if len(bbox) != 4:
                issues.append(f"Annotation ID {ann['id']} has an invalid bbox (must have 4 elements).")
            else:
                x, y, w, h = bbox
                if w <= 0 or h <= 0:
                    issues.append(f"Annotation ID {ann['id']} has a non-positive bbox (w={w}, h={h}).")
                if image_id in images:
                    img = images[image_id]
                    if x < 0 or y < 0 or x + w > img["width"] or y + h > img["height"]:
                        issues.append(
                            f"Annotation ID {ann['id']} has a bbox out of image bounds (image_id={image_id})."
                        )
        else:
            issues.append(f"Annotation ID {ann['id']} is missing bbox.")

    # Check categories
    for cat_id in categories.keys():
        if not isinstance(cat_id, int):
            issues.append(f"Category ID {cat_id} is not an integer.")

    # Summary
    if issues:
        print("\nValidation Issues Found:")
        for issue in issues:
            print(f"- {issue}")
        print(f"\nTotal Issues: {len(issues)}")
    else:
        print("\nAll annotations are valid!")

    return not bool(issues)


# Test the function
coco_file = "combined_annotations.json"  # Replace with your COCO JSON file
is_valid = validate_coco_annotations(coco_file)
if is_valid:
    print("\nDataset validation passed!")
else:
    print("\nDataset validation failed. See issues above.")
# Out:
# Total Images: 106466
# Total Annotations: 119244
# Total Categories: 1
#
# Validation Issues Found:
# - Annotation ID 85 has a bbox out of image bounds (image_id=86).
# - Annotation ID 86 has a bbox out of image bounds (image_id=87).
# - Annotation ID 87 has a bbox out of image bounds (image_id=88).
# - Annotation ID 2694 has a bbox out of image bounds (image_id=2732).
# - Annotation ID 2695 has a bbox out of image bounds (image_id=2733).
# - Annotation ID 2696 has a bbox out of image bounds (image_id=2734).
# - Annotation ID 2697 has a bbox out of image bounds (image_id=2735).
# - Annotation ID 2698 has a bbox out of image bounds (image_id=2736).
# - Annotation ID 2699 has a bbox out of image bounds (image_id=2737).
# - Annotation ID 2700 has a bbox out of image bounds (image_id=2738).
# - Annotation ID 2701 has a bbox out of image bounds (image_id=2739).
# - Annotation ID 2702 has a bbox out of image bounds (image_id=2740).
# - Annotation ID 2703 has a bbox out of image bounds (image_id=2741).
# - Annotation ID 2704 has a bbox out of image bounds (image_id=2742).
# - Annotation ID 2705 has a bbox out of image bounds (image_id=2743).
# - Annotation ID 2706 has a bbox out of image bounds (image_id=2744).
# - Annotation ID 2707 has a bbox out of image bounds (image_id=2745).
# - Annotation ID 2708 has a bbox out of image bounds (image_id=2746).
# - Annotation ID 2709 has a bbox out of image bounds (image_id=2747).
# - Annotation ID 2710 has a bbox out of image bounds (image_id=2748).
# - Annotation ID 2711 has a bbox out of image bounds (image_id=2749).
# - Annotation ID 2712 has a bbox out of image bounds (image_id=2750).
# - Annotation ID 2713 has a bbox out of image bounds (image_id=2751).
# - Annotation ID 2714 has a bbox out of image bounds (image_id=2752).
# - Annotation ID 2715 has a bbox out of image bounds (image_id=2753).
# - Annotation ID 2716 has a bbox out of image bounds (image_id=2754).
# - Annotation ID 2717 has a bbox out of image bounds (image_id=2755).
# - Annotation ID 2718 has a bbox out of image bounds (image_id=2756).
# - Annotation ID 2719 has a bbox out of image bounds (image_id=2757).
# - Annotation ID 2720 has a bbox out of image bounds (image_id=2758).
# - Annotation ID 2721 has a bbox out of image bounds (image_id=2759).
# - Annotation ID 2722 has a bbox out of image bounds (image_id=2760).
# - Annotation ID 2723 has a bbox out of image bounds (image_id=2761).
# - Annotation ID 2724 has a bbox out of image bounds (image_id=2762).
# - Annotation ID 2725 has a bbox out of image bounds (image_id=2763).
# - Annotation ID 2726 has a bbox out of image bounds (image_id=2764).
# - Annotation ID 2727 has a bbox out of image bounds (image_id=2765).
# - Annotation ID 2728 has a bbox out of image bounds (image_id=2766).
# - Annotation ID 2729 has a bbox out of image bounds (image_id=2767).
# - Annotation ID 2730 has a bbox out of image bounds (image_id=2768).
# - Annotation ID 2731 has a bbox out of image bounds (image_id=2769).
# - Annotation ID 2732 has a bbox out of image bounds (image_id=2770).
# - Annotation ID 2733 has a bbox out of image bounds (image_id=2771).
# - Annotation ID 2734 has a bbox out of image bounds (image_id=2772).
# - Annotation ID 2735 has a bbox out of image bounds (image_id=2773).
# - Annotation ID 2736 has a bbox out of image bounds (image_id=2774).
# - Annotation ID 2737 has a bbox out of image bounds (image_id=2775).
# - Annotation ID 2738 has a bbox out of image bounds (image_id=2776).
# - Annotation ID 2739 has a bbox out of image bounds (image_id=2777).
# - Annotation ID 2740 has a bbox out of image bounds (image_id=2778).
# - Annotation ID 2741 has a bbox out of image bounds (image_id=2779).
# - Annotation ID 2742 has a bbox out of image bounds (image_id=2780).
# - Annotation ID 2743 has a bbox out of image bounds (image_id=2781).
# - Annotation ID 2744 has a bbox out of image bounds (image_id=2782).
# - Annotation ID 2745 has a bbox out of image bounds (image_id=2783).
# - Annotation ID 2746 has a bbox out of image bounds (image_id=2784).
# - Annotation ID 2747 has a bbox out of image bounds (image_id=2785).
# - Annotation ID 2748 has a bbox out of image bounds (image_id=2786).
# - Annotation ID 2749 has a bbox out of image bounds (image_id=2787).
# - Annotation ID 2750 has a bbox out of image bounds (image_id=2788).
# - Annotation ID 2751 has a bbox out of image bounds (image_id=2789).
# - Annotation ID 2752 has a bbox out of image bounds (image_id=2790).
# - Annotation ID 2753 has a bbox out of image bounds (image_id=2791).
# - Annotation ID 2754 has a bbox out of image bounds (image_id=2792).
# - Annotation ID 2755 has a bbox out of image bounds (image_id=2793).
# - Annotation ID 2756 has a bbox out of image bounds (image_id=2794).
# - Annotation ID 2757 has a bbox out of image bounds (image_id=2795).
# - Annotation ID 2758 has a bbox out of image bounds (image_id=2796).
# - Annotation ID 2759 has a bbox out of image bounds (image_id=2797).
# - Annotation ID 2760 has a bbox out of image bounds (image_id=2798).
# - Annotation ID 2761 has a bbox out of image bounds (image_id=2799).
# - Annotation ID 2762 has a bbox out of image bounds (image_id=2800).
# - Annotation ID 2763 has a bbox out of image bounds (image_id=2801).
# - Annotation ID 2764 has a bbox out of image bounds (image_id=2802).
# - Annotation ID 2765 has a bbox out of image bounds (image_id=2803).
# - Annotation ID 2766 has a bbox out of image bounds (image_id=2804).
# - Annotation ID 2767 has a bbox out of image bounds (image_id=2805).
# - Annotation ID 2768 has a bbox out of image bounds (image_id=2806).
# - Annotation ID 2769 has a bbox out of image bounds (image_id=2807).
# - Annotation ID 2770 has a bbox out of image bounds (image_id=2808).
# - Annotation ID 2771 has a bbox out of image bounds (image_id=2809).
# - Annotation ID 2772 has a bbox out of image bounds (image_id=2810).
# - Annotation ID 2773 has a bbox out of image bounds (image_id=2811).
# - Annotation ID 2774 has a bbox out of image bounds (image_id=2812).
# - Annotation ID 2775 has a bbox out of image bounds (image_id=2813).
# - Annotation ID 2776 has a bbox out of image bounds (image_id=2814).
# - Annotation ID 2777 has a bbox out of image bounds (image_id=2815).
# - Annotation ID 2778 has a bbox out of image bounds (image_id=2816).
# - Annotation ID 2779 has a bbox out of image bounds (image_id=2817).
# - Annotation ID 2780 has a bbox out of image bounds (image_id=2818).
# - Annotation ID 2781 has a bbox out of image bounds (image_id=2819).
# - Annotation ID 2782 has a bbox out of image bounds (image_id=2820).
# - Annotation ID 2783 has a bbox out of image bounds (image_id=2821).
# - Annotation ID 2784 has a bbox out of image bounds (image_id=2822).
# - Annotation ID 2785 has a bbox out of image bounds (image_id=2823).
# - Annotation ID 2786 has a bbox out of image bounds (image_id=2824).
# - Annotation ID 2787 has a bbox out of image bounds (image_id=2825).
# - Annotation ID 2788 has a bbox out of image bounds (image_id=2826).
# - Annotation ID 2789 has a bbox out of image bounds (image_id=2827).
# - Annotation ID 2790 has a bbox out of image bounds (image_id=2828).
# - Annotation ID 2791 has a bbox out of image bounds (image_id=2829).
# - Annotation ID 2792 has a bbox out of image bounds (image_id=2830).
# - Annotation ID 2793 has a bbox out of image bounds (image_id=2831).
# - Annotation ID 2794 has a bbox out of image bounds (image_id=2832).
# - Annotation ID 2795 has a bbox out of image bounds (image_id=2833).
# - Annotation ID 2796 has a bbox out of image bounds (image_id=2834).
# - Annotation ID 2797 has a bbox out of image bounds (image_id=2835).
# - Annotation ID 2798 has a bbox out of image bounds (image_id=2836).
# - Annotation ID 2799 has a bbox out of image bounds (image_id=2837).
# - Annotation ID 2800 has a bbox out of image bounds (image_id=2838).
# - Annotation ID 2801 has a bbox out of image bounds (image_id=2839).
# - Annotation ID 2802 has a bbox out of image bounds (image_id=2840).
# - Annotation ID 2803 has a bbox out of image bounds (image_id=2841).
# - Annotation ID 2804 has a bbox out of image bounds (image_id=2842).
# - Annotation ID 2805 has a bbox out of image bounds (image_id=2843).
# - Annotation ID 2806 has a bbox out of image bounds (image_id=2844).
# - Annotation ID 2807 has a bbox out of image bounds (image_id=2845).
# - Annotation ID 2808 has a bbox out of image bounds (image_id=2846).
# - Annotation ID 2809 has a bbox out of image bounds (image_id=2847).
# - Annotation ID 2810 has a bbox out of image bounds (image_id=2848).
# - Annotation ID 2811 has a bbox out of image bounds (image_id=2849).
# - Annotation ID 2812 has a bbox out of image bounds (image_id=2850).
# - Annotation ID 2813 has a bbox out of image bounds (image_id=2851).
# - Annotation ID 2814 has a bbox out of image bounds (image_id=2852).
# - Annotation ID 2815 has a bbox out of image bounds (image_id=2853).
# - Annotation ID 2816 has a bbox out of image bounds (image_id=2854).
# - Annotation ID 2817 has a bbox out of image bounds (image_id=2855).
# - Annotation ID 2818 has a bbox out of image bounds (image_id=2856).
# - Annotation ID 2819 has a bbox out of image bounds (image_id=2857).
# - Annotation ID 2820 has a bbox out of image bounds (image_id=2858).
# - Annotation ID 2821 has a bbox out of image bounds (image_id=2859).
# - Annotation ID 2822 has a bbox out of image bounds (image_id=2860).
# - Annotation ID 2823 has a bbox out of image bounds (image_id=2861).
# - Annotation ID 2824 has a bbox out of image bounds (image_id=2862).
# - Annotation ID 2825 has a bbox out of image bounds (image_id=2863).
# - Annotation ID 2826 has a bbox out of image bounds (image_id=2864).
# - Annotation ID 2827 has a bbox out of image bounds (image_id=2865).
# - Annotation ID 2828 has a bbox out of image bounds (image_id=2866).
# - Annotation ID 2829 has a bbox out of image bounds (image_id=2867).
# - Annotation ID 2830 has a bbox out of image bounds (image_id=2868).
# - Annotation ID 2831 has a bbox out of image bounds (image_id=2869).
# - Annotation ID 2832 has a bbox out of image bounds (image_id=2870).
# - Annotation ID 2833 has a bbox out of image bounds (image_id=2871).
# - Annotation ID 2834 has a bbox out of image bounds (image_id=2872).
# - Annotation ID 2835 has a bbox out of image bounds (image_id=2873).
# - Annotation ID 2836 has a bbox out of image bounds (image_id=2874).
# - Annotation ID 2837 has a bbox out of image bounds (image_id=2875).
# - Annotation ID 2838 has a bbox out of image bounds (image_id=2876).
# - Annotation ID 2839 has a bbox out of image bounds (image_id=2877).
# - Annotation ID 2840 has a bbox out of image bounds (image_id=2878).
# - Annotation ID 2841 has a bbox out of image bounds (image_id=2879).
# - Annotation ID 2842 has a bbox out of image bounds (image_id=2880).
# - Annotation ID 2843 has a bbox out of image bounds (image_id=2881).
# - Annotation ID 2844 has a bbox out of image bounds (image_id=2882).
# - Annotation ID 2845 has a bbox out of image bounds (image_id=2883).
# - Annotation ID 2846 has a bbox out of image bounds (image_id=2884).
# - Annotation ID 2847 has a bbox out of image bounds (image_id=2885).
# - Annotation ID 2848 has a bbox out of image bounds (image_id=2886).
# - Annotation ID 2849 has a bbox out of image bounds (image_id=2887).
# - Annotation ID 2850 has a bbox out of image bounds (image_id=2888).
# - Annotation ID 2851 has a bbox out of image bounds (image_id=2889).
# - Annotation ID 2852 has a bbox out of image bounds (image_id=2890).
# - Annotation ID 2853 has a bbox out of image bounds (image_id=2891).
# - Annotation ID 2854 has a bbox out of image bounds (image_id=2892).
# - Annotation ID 2855 has a bbox out of image bounds (image_id=2893).
# - Annotation ID 2856 has a bbox out of image bounds (image_id=2894).
# - Annotation ID 2857 has a bbox out of image bounds (image_id=2895).
# - Annotation ID 2858 has a bbox out of image bounds (image_id=2896).
# - Annotation ID 2859 has a bbox out of image bounds (image_id=2897).
# - Annotation ID 2860 has a bbox out of image bounds (image_id=2898).
# - Annotation ID 2861 has a bbox out of image bounds (image_id=2899).
# - Annotation ID 2862 has a bbox out of image bounds (image_id=2900).
# - Annotation ID 2863 has a bbox out of image bounds (image_id=2901).
# - Annotation ID 2864 has a bbox out of image bounds (image_id=2902).
# - Annotation ID 2865 has a bbox out of image bounds (image_id=2903).
# - Annotation ID 2866 has a bbox out of image bounds (image_id=2904).
# - Annotation ID 2867 has a bbox out of image bounds (image_id=2905).
# - Annotation ID 2868 has a bbox out of image bounds (image_id=2906).
# - Annotation ID 2869 has a bbox out of image bounds (image_id=2907).
# - Annotation ID 2870 has a bbox out of image bounds (image_id=2908).
# - Annotation ID 2871 has a bbox out of image bounds (image_id=2909).
# - Annotation ID 2872 has a bbox out of image bounds (image_id=2910).
# - Annotation ID 2873 has a bbox out of image bounds (image_id=2911).
# - Annotation ID 2874 has a bbox out of image bounds (image_id=2912).
# - Annotation ID 2875 has a bbox out of image bounds (image_id=2913).
# - Annotation ID 2876 has a bbox out of image bounds (image_id=2914).
# - Annotation ID 2877 has a bbox out of image bounds (image_id=2915).
# - Annotation ID 2878 has a bbox out of image bounds (image_id=2916).
# - Annotation ID 2879 has a bbox out of image bounds (image_id=2917).
# - Annotation ID 2880 has a bbox out of image bounds (image_id=2918).
# - Annotation ID 2881 has a bbox out of image bounds (image_id=2919).
# - Annotation ID 2882 has a bbox out of image bounds (image_id=2920).
# - Annotation ID 2883 has a bbox out of image bounds (image_id=2921).
# - Annotation ID 2884 has a bbox out of image bounds (image_id=2922).
# - Annotation ID 2885 has a bbox out of image bounds (image_id=2923).
# - Annotation ID 2886 has a bbox out of image bounds (image_id=2924).
# - Annotation ID 2887 has a bbox out of image bounds (image_id=2925).
# - Annotation ID 2888 has a bbox out of image bounds (image_id=2926).
# - Annotation ID 2889 has a bbox out of image bounds (image_id=2927).
# - Annotation ID 2890 has a bbox out of image bounds (image_id=2928).
# - Annotation ID 2891 has a bbox out of image bounds (image_id=2929).
# - Annotation ID 2892 has a bbox out of image bounds (image_id=2930).
# - Annotation ID 2893 has a bbox out of image bounds (image_id=2931).
# - Annotation ID 2894 has a bbox out of image bounds (image_id=2932).
# - Annotation ID 2895 has a bbox out of image bounds (image_id=2933).
# - Annotation ID 2896 has a bbox out of image bounds (image_id=2934).
# - Annotation ID 2897 has a bbox out of image bounds (image_id=2935).
# - Annotation ID 2898 has a bbox out of image bounds (image_id=2936).
# - Annotation ID 2899 has a bbox out of image bounds (image_id=2937).
# - Annotation ID 2900 has a bbox out of image bounds (image_id=2938).
# - Annotation ID 2901 has a bbox out of image bounds (image_id=2939).
# - Annotation ID 2902 has a bbox out of image bounds (image_id=2940).
# - Annotation ID 2903 has a bbox out of image bounds (image_id=2941).
# - Annotation ID 2904 has a bbox out of image bounds (image_id=2942).
# - Annotation ID 2905 has a bbox out of image bounds (image_id=2943).
# - Annotation ID 2906 has a bbox out of image bounds (image_id=2944).
# - Annotation ID 2907 has a bbox out of image bounds (image_id=2945).
# - Annotation ID 2908 has a bbox out of image bounds (image_id=2946).
# - Annotation ID 2909 has a bbox out of image bounds (image_id=2947).
# - Annotation ID 2910 has a bbox out of image bounds (image_id=2948).
# - Annotation ID 2911 has a bbox out of image bounds (image_id=2949).
# - Annotation ID 2912 has a bbox out of image bounds (image_id=2950).
# - Annotation ID 2913 has a bbox out of image bounds (image_id=2951).
# - Annotation ID 2914 has a bbox out of image bounds (image_id=2952).
# - Annotation ID 2915 has a bbox out of image bounds (image_id=2953).
# - Annotation ID 2916 has a bbox out of image bounds (image_id=2954).
# - Annotation ID 2917 has a bbox out of image bounds (image_id=2955).
# - Annotation ID 2918 has a bbox out of image bounds (image_id=2956).
# - Annotation ID 2919 has a bbox out of image bounds (image_id=2957).
# - Annotation ID 2920 has a bbox out of image bounds (image_id=2958).
# - Annotation ID 2921 has a bbox out of image bounds (image_id=2959).
# - Annotation ID 2922 has a bbox out of image bounds (image_id=2960).
# - Annotation ID 2923 has a bbox out of image bounds (image_id=2961).
# - Annotation ID 2924 has a bbox out of image bounds (image_id=2962).
# - Annotation ID 2925 has a bbox out of image bounds (image_id=2963).
# - Annotation ID 2926 has a bbox out of image bounds (image_id=2964).
# - Annotation ID 2927 has a bbox out of image bounds (image_id=2965).
# - Annotation ID 2928 has a bbox out of image bounds (image_id=2966).
# - Annotation ID 2929 has a bbox out of image bounds (image_id=2967).
# - Annotation ID 2930 has a bbox out of image bounds (image_id=2968).
# - Annotation ID 2931 has a bbox out of image bounds (image_id=2969).
# - Annotation ID 2932 has a bbox out of image bounds (image_id=2970).
# - Annotation ID 2933 has a bbox out of image bounds (image_id=2971).
# - Annotation ID 2934 has a bbox out of image bounds (image_id=2972).
# - Annotation ID 2935 has a bbox out of image bounds (image_id=2973).
# - Annotation ID 2936 has a bbox out of image bounds (image_id=2974).
# - Annotation ID 2937 has a bbox out of image bounds (image_id=2975).
# - Annotation ID 2938 has a bbox out of image bounds (image_id=2976).
# - Annotation ID 2939 has a bbox out of image bounds (image_id=2977).
# - Annotation ID 2940 has a bbox out of image bounds (image_id=2978).
# - Annotation ID 2941 has a bbox out of image bounds (image_id=2979).
# - Annotation ID 2942 has a bbox out of image bounds (image_id=2980).
# - Annotation ID 2943 has a bbox out of image bounds (image_id=2981).
# - Annotation ID 2944 has a bbox out of image bounds (image_id=2982).
# - Annotation ID 2945 has a bbox out of image bounds (image_id=2983).
# - Annotation ID 2946 has a bbox out of image bounds (image_id=2984).
# - Annotation ID 2947 has a bbox out of image bounds (image_id=2985).
# - Annotation ID 2948 has a bbox out of image bounds (image_id=2986).
# - Annotation ID 2949 has a bbox out of image bounds (image_id=2987).
# - Annotation ID 2950 has a bbox out of image bounds (image_id=2988).
# - Annotation ID 2951 has a bbox out of image bounds (image_id=2989).
# - Annotation ID 2952 has a bbox out of image bounds (image_id=2990).
# - Annotation ID 2953 has a bbox out of image bounds (image_id=2991).
# - Annotation ID 2954 has a bbox out of image bounds (image_id=2992).
# - Annotation ID 2955 has a bbox out of image bounds (image_id=2993).
# - Annotation ID 2956 has a bbox out of image bounds (image_id=2994).
# - Annotation ID 2957 has a bbox out of image bounds (image_id=2995).
# - Annotation ID 2958 has a bbox out of image bounds (image_id=2996).
# - Annotation ID 2959 has a bbox out of image bounds (image_id=2997).
# - Annotation ID 2960 has a bbox out of image bounds (image_id=2998).
# - Annotation ID 2961 has a bbox out of image bounds (image_id=2999).
# - Annotation ID 2962 has a bbox out of image bounds (image_id=3000).
# - Annotation ID 2963 has a bbox out of image bounds (image_id=3001).
# - Annotation ID 2964 has a bbox out of image bounds (image_id=3002).
# - Annotation ID 2965 has a bbox out of image bounds (image_id=3003).
# - Annotation ID 2966 has a bbox out of image bounds (image_id=3004).
# - Annotation ID 2967 has a bbox out of image bounds (image_id=3005).
# - Annotation ID 2968 has a bbox out of image bounds (image_id=3006).
# - Annotation ID 2969 has a bbox out of image bounds (image_id=3007).
# - Annotation ID 2970 has a bbox out of image bounds (image_id=3008).
# - Annotation ID 2971 has a bbox out of image bounds (image_id=3009).
# - Annotation ID 2972 has a bbox out of image bounds (image_id=3010).
# - Annotation ID 2973 has a bbox out of image bounds (image_id=3011).
# - Annotation ID 2974 has a bbox out of image bounds (image_id=3012).
# - Annotation ID 2975 has a bbox out of image bounds (image_id=3013).
# - Annotation ID 2976 has a bbox out of image bounds (image_id=3014).
# - Annotation ID 2977 has a bbox out of image bounds (image_id=3015).
# - Annotation ID 2978 has a bbox out of image bounds (image_id=3016).
# - Annotation ID 2979 has a bbox out of image bounds (image_id=3017).
# - Annotation ID 2980 has a bbox out of image bounds (image_id=3018).
# - Annotation ID 2981 has a bbox out of image bounds (image_id=3019).
# - Annotation ID 2982 has a bbox out of image bounds (image_id=3020).
# - Annotation ID 2983 has a bbox out of image bounds (image_id=3021).
# - Annotation ID 2984 has a bbox out of image bounds (image_id=3022).
# - Annotation ID 2985 has a bbox out of image bounds (image_id=3023).
# - Annotation ID 2986 has a bbox out of image bounds (image_id=3024).
# - Annotation ID 2987 has a bbox out of image bounds (image_id=3025).
# - Annotation ID 2988 has a bbox out of image bounds (image_id=3026).
# - Annotation ID 2989 has a bbox out of image bounds (image_id=3027).
# - Annotation ID 2990 has a bbox out of image bounds (image_id=3028).
# - Annotation ID 2991 has a bbox out of image bounds (image_id=3029).
# - Annotation ID 2992 has a bbox out of image bounds (image_id=3030).
# - Annotation ID 2993 has a bbox out of image bounds (image_id=3031).
# - Annotation ID 2994 has a bbox out of image bounds (image_id=3032).
# - Annotation ID 2995 has a bbox out of image bounds (image_id=3033).
# - Annotation ID 2996 has a bbox out of image bounds (image_id=3034).
# - Annotation ID 2997 has a bbox out of image bounds (image_id=3035).
# - Annotation ID 2998 has a bbox out of image bounds (image_id=3036).
# - Annotation ID 2999 has a bbox out of image bounds (image_id=3037).
# - Annotation ID 3000 has a bbox out of image bounds (image_id=3038).
# - Annotation ID 3001 has a bbox out of image bounds (image_id=3039).
# - Annotation ID 3002 has a bbox out of image bounds (image_id=3040).
# - Annotation ID 3003 has a bbox out of image bounds (image_id=3041).
# - Annotation ID 3004 has a bbox out of image bounds (image_id=3042).
# - Annotation ID 3005 has a bbox out of image bounds (image_id=3043).
# - Annotation ID 3006 has a bbox out of image bounds (image_id=3044).
# - Annotation ID 3007 has a bbox out of image bounds (image_id=3045).
# - Annotation ID 3008 has a bbox out of image bounds (image_id=3046).
# - Annotation ID 3009 has a bbox out of image bounds (image_id=3047).
# - Annotation ID 3010 has a bbox out of image bounds (image_id=3048).
# - Annotation ID 3011 has a bbox out of image bounds (image_id=3049).
# - Annotation ID 3012 has a bbox out of image bounds (image_id=3050).
# - Annotation ID 3013 has a bbox out of image bounds (image_id=3051).
# - Annotation ID 3014 has a bbox out of image bounds (image_id=3052).
# - Annotation ID 3015 has a bbox out of image bounds (image_id=3053).
# - Annotation ID 3016 has a bbox out of image bounds (image_id=3054).
# - Annotation ID 3068 has a bbox out of image bounds (image_id=3106).
# - Annotation ID 3069 has a bbox out of image bounds (image_id=3107).
# - Annotation ID 3070 has a bbox out of image bounds (image_id=3108).
# - Annotation ID 3071 has a bbox out of image bounds (image_id=3109).
# - Annotation ID 3072 has a bbox out of image bounds (image_id=3110).
# - Annotation ID 3073 has a bbox out of image bounds (image_id=3111).
# - Annotation ID 3074 has a bbox out of image bounds (image_id=3112).
# - Annotation ID 3075 has a bbox out of image bounds (image_id=3113).
# - Annotation ID 3076 has a bbox out of image bounds (image_id=3114).
# - Annotation ID 3077 has a bbox out of image bounds (image_id=3115).
# - Annotation ID 3078 has a bbox out of image bounds (image_id=3116).
# - Annotation ID 3079 has a bbox out of image bounds (image_id=3117).
# - Annotation ID 3080 has a bbox out of image bounds (image_id=3118).
# - Annotation ID 3952 has a bbox out of image bounds (image_id=3990).
# - Annotation ID 3953 has a bbox out of image bounds (image_id=3991).
# - Annotation ID 3954 has a bbox out of image bounds (image_id=3992).
# - Annotation ID 3955 has a bbox out of image bounds (image_id=4070).
# - Annotation ID 3956 has a bbox out of image bounds (image_id=4071).
# - Annotation ID 3957 has a bbox out of image bounds (image_id=4072).
# - Annotation ID 4018 has a bbox out of image bounds (image_id=4133).
# - Annotation ID 4019 has a bbox out of image bounds (image_id=4134).
# - Annotation ID 4020 has a bbox out of image bounds (image_id=4135).
# - Annotation ID 4021 has a bbox out of image bounds (image_id=4136).
# - Annotation ID 4022 has a bbox out of image bounds (image_id=4137).
# - Annotation ID 4023 has a bbox out of image bounds (image_id=4138).
# - Annotation ID 4024 has a bbox out of image bounds (image_id=4139).
# - Annotation ID 4025 has a bbox out of image bounds (image_id=4140).
# - Annotation ID 4026 has a bbox out of image bounds (image_id=4141).
# - Annotation ID 4027 has a bbox out of image bounds (image_id=4142).
# - Annotation ID 4028 has a bbox out of image bounds (image_id=4143).
# - Annotation ID 4029 has a bbox out of image bounds (image_id=4144).
# - Annotation ID 4030 has a bbox out of image bounds (image_id=4145).
# - Annotation ID 4031 has a bbox out of image bounds (image_id=4146).
# - Annotation ID 4032 has a bbox out of image bounds (image_id=4147).
# - Annotation ID 4033 has a bbox out of image bounds (image_id=4148).
# - Annotation ID 4034 has a bbox out of image bounds (image_id=4149).
# - Annotation ID 4035 has a bbox out of image bounds (image_id=4150).
# - Annotation ID 4036 has a bbox out of image bounds (image_id=4151).
# - Annotation ID 4037 has a bbox out of image bounds (image_id=4152).
# - Annotation ID 4038 has a bbox out of image bounds (image_id=4153).
# - Annotation ID 4039 has a bbox out of image bounds (image_id=4154).
# - Annotation ID 4040 has a bbox out of image bounds (image_id=4155).
# - Annotation ID 4041 has a bbox out of image bounds (image_id=4156).
# - Annotation ID 4042 has a bbox out of image bounds (image_id=4157).
# - Annotation ID 4043 has a bbox out of image bounds (image_id=4158).
# - Annotation ID 4044 has a bbox out of image bounds (image_id=4159).
# - Annotation ID 4045 has a bbox out of image bounds (image_id=4160).
# - Annotation ID 4046 has a bbox out of image bounds (image_id=4161).
# - Annotation ID 4047 has a bbox out of image bounds (image_id=4162).
# - Annotation ID 4048 has a bbox out of image bounds (image_id=4163).
# - Annotation ID 4049 has a bbox out of image bounds (image_id=4164).
# - Annotation ID 4050 has a bbox out of image bounds (image_id=4165).
# - Annotation ID 4051 has a bbox out of image bounds (image_id=4166).
# - Annotation ID 4052 has a bbox out of image bounds (image_id=4167).
# - Annotation ID 4053 has a bbox out of image bounds (image_id=4168).
# - Annotation ID 4054 has a bbox out of image bounds (image_id=4169).
# - Annotation ID 4055 has a bbox out of image bounds (image_id=4170).
# - Annotation ID 4056 has a bbox out of image bounds (image_id=4171).
# - Annotation ID 4057 has a bbox out of image bounds (image_id=4172).
# - Annotation ID 4058 has a bbox out of image bounds (image_id=4173).
# - Annotation ID 4059 has a bbox out of image bounds (image_id=4174).
# - Annotation ID 4060 has a bbox out of image bounds (image_id=4175).
# - Annotation ID 4061 has a bbox out of image bounds (image_id=4176).
# - Annotation ID 4062 has a bbox out of image bounds (image_id=4177).
# - Annotation ID 4063 has a bbox out of image bounds (image_id=4178).
# - Annotation ID 4064 has a bbox out of image bounds (image_id=4179).
# - Annotation ID 4065 has a bbox out of image bounds (image_id=4180).
# - Annotation ID 4066 has a bbox out of image bounds (image_id=4181).
# - Annotation ID 4067 has a bbox out of image bounds (image_id=4182).
# - Annotation ID 4068 has a bbox out of image bounds (image_id=4183).
# - Annotation ID 4069 has a bbox out of image bounds (image_id=4184).
# - Annotation ID 4070 has a bbox out of image bounds (image_id=4185).
# - Annotation ID 4071 has a bbox out of image bounds (image_id=4186).
# - Annotation ID 4072 has a bbox out of image bounds (image_id=4187).
# - Annotation ID 4073 has a bbox out of image bounds (image_id=4188).
# - Annotation ID 4074 has a bbox out of image bounds (image_id=4189).
# - Annotation ID 4075 has a bbox out of image bounds (image_id=4190).
# - Annotation ID 4076 has a bbox out of image bounds (image_id=4191).
# - Annotation ID 4077 has a bbox out of image bounds (image_id=4192).
# - Annotation ID 4078 has a bbox out of image bounds (image_id=4193).
# - Annotation ID 4079 has a bbox out of image bounds (image_id=4194).
# - Annotation ID 4080 has a bbox out of image bounds (image_id=4195).
# - Annotation ID 4081 has a bbox out of image bounds (image_id=4196).
# - Annotation ID 4082 has a bbox out of image bounds (image_id=4197).
# - Annotation ID 4083 has a bbox out of image bounds (image_id=4198).
# - Annotation ID 4084 has a bbox out of image bounds (image_id=4199).
# - Annotation ID 4085 has a bbox out of image bounds (image_id=4200).
# - Annotation ID 4086 has a bbox out of image bounds (image_id=4201).
# - Annotation ID 4087 has a bbox out of image bounds (image_id=4202).
# - Annotation ID 4088 has a bbox out of image bounds (image_id=4203).
# - Annotation ID 4089 has a bbox out of image bounds (image_id=4204).
# - Annotation ID 4090 has a bbox out of image bounds (image_id=4205).
# - Annotation ID 4091 has a bbox out of image bounds (image_id=4206).
# - Annotation ID 4092 has a bbox out of image bounds (image_id=4207).
# - Annotation ID 4093 has a bbox out of image bounds (image_id=4208).
# - Annotation ID 4094 has a bbox out of image bounds (image_id=4209).
# - Annotation ID 4095 has a bbox out of image bounds (image_id=4210).
# - Annotation ID 4096 has a bbox out of image bounds (image_id=4211).
# - Annotation ID 4097 has a bbox out of image bounds (image_id=4212).
# - Annotation ID 4098 has a bbox out of image bounds (image_id=4213).
# - Annotation ID 4099 has a bbox out of image bounds (image_id=4214).
# - Annotation ID 4100 has a bbox out of image bounds (image_id=4215).
# - Annotation ID 4101 has a bbox out of image bounds (image_id=4216).
# - Annotation ID 4102 has a bbox out of image bounds (image_id=4217).
# - Annotation ID 4103 has a bbox out of image bounds (image_id=4218).
# - Annotation ID 4104 has a bbox out of image bounds (image_id=4219).
# - Annotation ID 4105 has a bbox out of image bounds (image_id=4220).
# - Annotation ID 4106 has a bbox out of image bounds (image_id=4221).
# - Annotation ID 4107 has a bbox out of image bounds (image_id=4222).
# - Annotation ID 4108 has a bbox out of image bounds (image_id=4223).
# - Annotation ID 4109 has a bbox out of image bounds (image_id=4224).
# - Annotation ID 4110 has a bbox out of image bounds (image_id=4225).
# - Annotation ID 4111 has a bbox out of image bounds (image_id=4226).
# - Annotation ID 4112 has a bbox out of image bounds (image_id=4227).
# - Annotation ID 4113 has a bbox out of image bounds (image_id=4228).
# - Annotation ID 4114 has a bbox out of image bounds (image_id=4229).
# - Annotation ID 4115 has a bbox out of image bounds (image_id=4230).
# - Annotation ID 4116 has a bbox out of image bounds (image_id=4231).
# - Annotation ID 4117 has a bbox out of image bounds (image_id=4232).
# - Annotation ID 4118 has a bbox out of image bounds (image_id=4233).
# - Annotation ID 4119 has a bbox out of image bounds (image_id=4234).
# - Annotation ID 4120 has a bbox out of image bounds (image_id=4235).
# - Annotation ID 4121 has a bbox out of image bounds (image_id=4236).
# - Annotation ID 4122 has a bbox out of image bounds (image_id=4237).
# - Annotation ID 4123 has a bbox out of image bounds (image_id=4238).
# - Annotation ID 4124 has a bbox out of image bounds (image_id=4239).
# - Annotation ID 4125 has a bbox out of image bounds (image_id=4240).
# - Annotation ID 4126 has a bbox out of image bounds (image_id=4241).
# - Annotation ID 4127 has a bbox out of image bounds (image_id=4242).
# - Annotation ID 4128 has a bbox out of image bounds (image_id=4243).
# - Annotation ID 4129 has a bbox out of image bounds (image_id=4244).
# - Annotation ID 4130 has a bbox out of image bounds (image_id=4245).
# - Annotation ID 4131 has a bbox out of image bounds (image_id=4246).
# - Annotation ID 4132 has a bbox out of image bounds (image_id=4247).
# - Annotation ID 4133 has a bbox out of image bounds (image_id=4248).
# - Annotation ID 4134 has a bbox out of image bounds (image_id=4249).
# - Annotation ID 4135 has a bbox out of image bounds (image_id=4250).
# - Annotation ID 4136 has a bbox out of image bounds (image_id=4251).
# - Annotation ID 4137 has a bbox out of image bounds (image_id=4252).
# - Annotation ID 4138 has a bbox out of image bounds (image_id=4253).
# - Annotation ID 4139 has a bbox out of image bounds (image_id=4254).
# - Annotation ID 4140 has a bbox out of image bounds (image_id=4255).
# - Annotation ID 4141 has a bbox out of image bounds (image_id=4256).
# - Annotation ID 4142 has a bbox out of image bounds (image_id=4257).
# - Annotation ID 4143 has a bbox out of image bounds (image_id=4258).
# - Annotation ID 4144 has a bbox out of image bounds (image_id=4259).
# - Annotation ID 4145 has a bbox out of image bounds (image_id=4260).
# - Annotation ID 4146 has a bbox out of image bounds (image_id=4261).
# - Annotation ID 4147 has a bbox out of image bounds (image_id=4262).
# - Annotation ID 4148 has a bbox out of image bounds (image_id=4263).
# - Annotation ID 4149 has a bbox out of image bounds (image_id=4264).
# - Annotation ID 4150 has a bbox out of image bounds (image_id=4265).
# - Annotation ID 4151 has a bbox out of image bounds (image_id=4266).
# - Annotation ID 4152 has a bbox out of image bounds (image_id=4267).
# - Annotation ID 4153 has a bbox out of image bounds (image_id=4268).
# - Annotation ID 4154 has a bbox out of image bounds (image_id=4269).
# - Annotation ID 4155 has a bbox out of image bounds (image_id=4270).
# - Annotation ID 4156 has a bbox out of image bounds (image_id=4271).
# - Annotation ID 4157 has a bbox out of image bounds (image_id=4272).
# - Annotation ID 4158 has a bbox out of image bounds (image_id=4273).
# - Annotation ID 4159 has a bbox out of image bounds (image_id=4274).
# - Annotation ID 4160 has a bbox out of image bounds (image_id=4275).
# - Annotation ID 4161 has a bbox out of image bounds (image_id=4276).
# - Annotation ID 4162 has a bbox out of image bounds (image_id=4277).
# - Annotation ID 4163 has a bbox out of image bounds (image_id=4278).
# - Annotation ID 4164 has a bbox out of image bounds (image_id=4279).
# - Annotation ID 4165 has a bbox out of image bounds (image_id=4280).
# - Annotation ID 4166 has a bbox out of image bounds (image_id=4281).
# - Annotation ID 4167 has a bbox out of image bounds (image_id=4282).
# - Annotation ID 4168 has a bbox out of image bounds (image_id=4283).
# - Annotation ID 4169 has a bbox out of image bounds (image_id=4284).
# - Annotation ID 4170 has a bbox out of image bounds (image_id=4285).
# - Annotation ID 4171 has a bbox out of image bounds (image_id=4286).
# - Annotation ID 4172 has a bbox out of image bounds (image_id=4287).
# - Annotation ID 4173 has a bbox out of image bounds (image_id=4288).
# - Annotation ID 4174 has a bbox out of image bounds (image_id=4289).
# - Annotation ID 4175 has a bbox out of image bounds (image_id=4290).
# - Annotation ID 4176 has a bbox out of image bounds (image_id=4291).
# - Annotation ID 4177 has a bbox out of image bounds (image_id=4292).
# - Annotation ID 4178 has a bbox out of image bounds (image_id=4293).
# - Annotation ID 4179 has a bbox out of image bounds (image_id=4294).
# - Annotation ID 4180 has a bbox out of image bounds (image_id=4295).
# - Annotation ID 4181 has a bbox out of image bounds (image_id=4296).
# - Annotation ID 4182 has a bbox out of image bounds (image_id=4297).
# - Annotation ID 4183 has a bbox out of image bounds (image_id=4298).
# - Annotation ID 4184 has a bbox out of image bounds (image_id=4299).
# - Annotation ID 4185 has a bbox out of image bounds (image_id=4300).
# - Annotation ID 4186 has a bbox out of image bounds (image_id=4301).
# - Annotation ID 4187 has a bbox out of image bounds (image_id=4302).
# - Annotation ID 4188 has a bbox out of image bounds (image_id=4303).
# - Annotation ID 4189 has a bbox out of image bounds (image_id=4304).
# - Annotation ID 4190 has a bbox out of image bounds (image_id=4305).
# - Annotation ID 4191 has a bbox out of image bounds (image_id=4306).
# - Annotation ID 4192 has a bbox out of image bounds (image_id=4307).
# - Annotation ID 4193 has a bbox out of image bounds (image_id=4308).
# - Annotation ID 4194 has a bbox out of image bounds (image_id=4309).
# - Annotation ID 4195 has a bbox out of image bounds (image_id=4310).
# - Annotation ID 4196 has a bbox out of image bounds (image_id=4311).
# - Annotation ID 4197 has a bbox out of image bounds (image_id=4312).
# - Annotation ID 4198 has a bbox out of image bounds (image_id=4313).
# - Annotation ID 4199 has a bbox out of image bounds (image_id=4314).
# - Annotation ID 4200 has a bbox out of image bounds (image_id=4315).
# - Annotation ID 4201 has a bbox out of image bounds (image_id=4316).
# - Annotation ID 4202 has a bbox out of image bounds (image_id=4317).
# - Annotation ID 4203 has a bbox out of image bounds (image_id=4318).
# - Annotation ID 4204 has a bbox out of image bounds (image_id=4319).
# - Annotation ID 4205 has a bbox out of image bounds (image_id=4320).
# - Annotation ID 4206 has a bbox out of image bounds (image_id=4321).
# - Annotation ID 4207 has a bbox out of image bounds (image_id=4322).
# - Annotation ID 4208 has a bbox out of image bounds (image_id=4323).
# - Annotation ID 4209 has a bbox out of image bounds (image_id=4324).
# - Annotation ID 4210 has a bbox out of image bounds (image_id=4325).
# - Annotation ID 4211 has a bbox out of image bounds (image_id=4326).
# - Annotation ID 4212 has a bbox out of image bounds (image_id=4327).
# - Annotation ID 4213 has a bbox out of image bounds (image_id=4328).
# - Annotation ID 4214 has a bbox out of image bounds (image_id=4329).
# - Annotation ID 4215 has a bbox out of image bounds (image_id=4330).
# - Annotation ID 4216 has a bbox out of image bounds (image_id=4331).
# - Annotation ID 4217 has a bbox out of image bounds (image_id=4332).
# - Annotation ID 4218 has a bbox out of image bounds (image_id=4333).
# - Annotation ID 4219 has a bbox out of image bounds (image_id=4334).
# - Annotation ID 4220 has a bbox out of image bounds (image_id=4335).
# - Annotation ID 4221 has a bbox out of image bounds (image_id=4336).
# - Annotation ID 4222 has a bbox out of image bounds (image_id=4337).
# - Annotation ID 4223 has a bbox out of image bounds (image_id=4338).
# - Annotation ID 4224 has a bbox out of image bounds (image_id=4339).
# - Annotation ID 4225 has a bbox out of image bounds (image_id=4340).
# - Annotation ID 4226 has a bbox out of image bounds (image_id=4341).
# - Annotation ID 4227 has a bbox out of image bounds (image_id=4342).
# - Annotation ID 4228 has a bbox out of image bounds (image_id=4343).
# - Annotation ID 4229 has a bbox out of image bounds (image_id=4344).
# - Annotation ID 4230 has a bbox out of image bounds (image_id=4345).
# - Annotation ID 4231 has a bbox out of image bounds (image_id=4346).
# - Annotation ID 4232 has a bbox out of image bounds (image_id=4347).
# - Annotation ID 4233 has a bbox out of image bounds (image_id=4348).
# - Annotation ID 4234 has a bbox out of image bounds (image_id=4349).
# - Annotation ID 4235 has a bbox out of image bounds (image_id=4350).
# - Annotation ID 4236 has a bbox out of image bounds (image_id=4351).
# - Annotation ID 4237 has a bbox out of image bounds (image_id=4352).
# - Annotation ID 4238 has a bbox out of image bounds (image_id=4353).
# - Annotation ID 4239 has a bbox out of image bounds (image_id=4354).
# - Annotation ID 4240 has a bbox out of image bounds (image_id=4355).
# - Annotation ID 4241 has a bbox out of image bounds (image_id=4356).
# - Annotation ID 4242 has a bbox out of image bounds (image_id=4357).
# - Annotation ID 4243 has a bbox out of image bounds (image_id=4358).
# - Annotation ID 4244 has a bbox out of image bounds (image_id=4359).
# - Annotation ID 4245 has a bbox out of image bounds (image_id=4360).
# - Annotation ID 4246 has a bbox out of image bounds (image_id=4361).
# - Annotation ID 4247 has a bbox out of image bounds (image_id=4362).
# - Annotation ID 4248 has a bbox out of image bounds (image_id=4363).
# - Annotation ID 4249 has a bbox out of image bounds (image_id=4364).
# - Annotation ID 4250 has a bbox out of image bounds (image_id=4365).
# - Annotation ID 4251 has a bbox out of image bounds (image_id=4366).
# - Annotation ID 4252 has a bbox out of image bounds (image_id=4367).
# - Annotation ID 4253 has a bbox out of image bounds (image_id=4368).
# - Annotation ID 4254 has a bbox out of image bounds (image_id=4369).
# - Annotation ID 4255 has a bbox out of image bounds (image_id=4370).
# - Annotation ID 4256 has a bbox out of image bounds (image_id=4371).
# - Annotation ID 4257 has a bbox out of image bounds (image_id=4372).
# - Annotation ID 4258 has a bbox out of image bounds (image_id=4373).
# - Annotation ID 4259 has a bbox out of image bounds (image_id=4374).
# - Annotation ID 4260 has a bbox out of image bounds (image_id=4375).
# - Annotation ID 4261 has a bbox out of image bounds (image_id=4376).
# - Annotation ID 4262 has a bbox out of image bounds (image_id=4377).
# - Annotation ID 4263 has a bbox out of image bounds (image_id=4378).
# - Annotation ID 4264 has a bbox out of image bounds (image_id=4379).
# - Annotation ID 4265 has a bbox out of image bounds (image_id=4380).
# - Annotation ID 4266 has a bbox out of image bounds (image_id=4381).
# - Annotation ID 4267 has a bbox out of image bounds (image_id=4382).
# - Annotation ID 4268 has a bbox out of image bounds (image_id=4383).
# - Annotation ID 4269 has a bbox out of image bounds (image_id=4384).
# - Annotation ID 4270 has a bbox out of image bounds (image_id=4385).
# - Annotation ID 4271 has a bbox out of image bounds (image_id=4386).
# - Annotation ID 4272 has a bbox out of image bounds (image_id=4387).
# - Annotation ID 4273 has a bbox out of image bounds (image_id=4388).
# - Annotation ID 4274 has a bbox out of image bounds (image_id=4389).
# - Annotation ID 4275 has a bbox out of image bounds (image_id=4390).
# - Annotation ID 4276 has a bbox out of image bounds (image_id=4391).
# - Annotation ID 4277 has a bbox out of image bounds (image_id=4392).
# - Annotation ID 4278 has a bbox out of image bounds (image_id=4393).
# - Annotation ID 4279 has a bbox out of image bounds (image_id=4394).
# - Annotation ID 4280 has a bbox out of image bounds (image_id=4395).
# - Annotation ID 4281 has a bbox out of image bounds (image_id=4396).
# - Annotation ID 4282 has a bbox out of image bounds (image_id=4397).
# - Annotation ID 4283 has a bbox out of image bounds (image_id=4398).
# - Annotation ID 4284 has a bbox out of image bounds (image_id=4399).
# - Annotation ID 4285 has a bbox out of image bounds (image_id=4400).
# - Annotation ID 4286 has a bbox out of image bounds (image_id=4401).
# - Annotation ID 4287 has a bbox out of image bounds (image_id=4402).
# - Annotation ID 4288 has a bbox out of image bounds (image_id=4403).
# - Annotation ID 4289 has a bbox out of image bounds (image_id=4404).
# - Annotation ID 4290 has a bbox out of image bounds (image_id=4405).
# - Annotation ID 4291 has a bbox out of image bounds (image_id=4406).
# - Annotation ID 4292 has a bbox out of image bounds (image_id=4407).
# - Annotation ID 4293 has a bbox out of image bounds (image_id=4408).
# - Annotation ID 4294 has a bbox out of image bounds (image_id=4409).
# - Annotation ID 4295 has a bbox out of image bounds (image_id=4410).
# - Annotation ID 4296 has a bbox out of image bounds (image_id=4411).
# - Annotation ID 4297 has a bbox out of image bounds (image_id=4412).
# - Annotation ID 4298 has a bbox out of image bounds (image_id=4413).
# - Annotation ID 4299 has a bbox out of image bounds (image_id=4414).
# - Annotation ID 4300 has a bbox out of image bounds (image_id=4415).
# - Annotation ID 4301 has a bbox out of image bounds (image_id=4416).
# - Annotation ID 4302 has a bbox out of image bounds (image_id=4417).
# - Annotation ID 4303 has a bbox out of image bounds (image_id=4418).
# - Annotation ID 4304 has a bbox out of image bounds (image_id=4419).
# - Annotation ID 4305 has a bbox out of image bounds (image_id=4420).
# - Annotation ID 4306 has a bbox out of image bounds (image_id=4421).
# - Annotation ID 4307 has a bbox out of image bounds (image_id=4422).
# - Annotation ID 4308 has a bbox out of image bounds (image_id=4423).
# - Annotation ID 4309 has a bbox out of image bounds (image_id=4424).
# - Annotation ID 4310 has a bbox out of image bounds (image_id=4425).
# - Annotation ID 4311 has a bbox out of image bounds (image_id=4426).
# - Annotation ID 4312 has a bbox out of image bounds (image_id=4427).
# - Annotation ID 4313 has a bbox out of image bounds (image_id=4428).
# - Annotation ID 4314 has a bbox out of image bounds (image_id=4429).
# - Annotation ID 4315 has a bbox out of image bounds (image_id=4430).
# - Annotation ID 4316 has a bbox out of image bounds (image_id=4431).
# - Annotation ID 4317 has a bbox out of image bounds (image_id=4432).
# - Annotation ID 4318 has a bbox out of image bounds (image_id=4433).
# - Annotation ID 4319 has a bbox out of image bounds (image_id=4434).
# - Annotation ID 4320 has a bbox out of image bounds (image_id=4435).
# - Annotation ID 4321 has a bbox out of image bounds (image_id=4436).
# - Annotation ID 4322 has a bbox out of image bounds (image_id=4437).
# - Annotation ID 4323 has a bbox out of image bounds (image_id=4438).
# - Annotation ID 4324 has a bbox out of image bounds (image_id=4439).
# - Annotation ID 4325 has a bbox out of image bounds (image_id=4440).
# - Annotation ID 4326 has a bbox out of image bounds (image_id=4441).
# - Annotation ID 4327 has a bbox out of image bounds (image_id=4442).
# - Annotation ID 4328 has a bbox out of image bounds (image_id=4443).
# - Annotation ID 4329 has a bbox out of image bounds (image_id=4444).
# - Annotation ID 4330 has a bbox out of image bounds (image_id=4445).
# - Annotation ID 4331 has a bbox out of image bounds (image_id=4446).
# - Annotation ID 4332 has a bbox out of image bounds (image_id=4447).
# - Annotation ID 4333 has a bbox out of image bounds (image_id=4448).
# - Annotation ID 4334 has a bbox out of image bounds (image_id=4449).
# - Annotation ID 4335 has a bbox out of image bounds (image_id=4450).
# - Annotation ID 4336 has a bbox out of image bounds (image_id=4451).
# - Annotation ID 4337 has a bbox out of image bounds (image_id=4452).
# - Annotation ID 4338 has a bbox out of image bounds (image_id=4453).
# - Annotation ID 4339 has a bbox out of image bounds (image_id=4454).
# - Annotation ID 4340 has a bbox out of image bounds (image_id=4455).
# - Annotation ID 4341 has a bbox out of image bounds (image_id=4456).
# - Annotation ID 4342 has a bbox out of image bounds (image_id=4457).
# - Annotation ID 4343 has a bbox out of image bounds (image_id=4458).
# - Annotation ID 4344 has a bbox out of image bounds (image_id=4459).
# - Annotation ID 4345 has a bbox out of image bounds (image_id=4460).
# - Annotation ID 4346 has a bbox out of image bounds (image_id=4461).
# - Annotation ID 4347 has a bbox out of image bounds (image_id=4462).
# - Annotation ID 4348 has a bbox out of image bounds (image_id=4463).
# - Annotation ID 4349 has a bbox out of image bounds (image_id=4464).
# - Annotation ID 4350 has a bbox out of image bounds (image_id=4465).
# - Annotation ID 4351 has a bbox out of image bounds (image_id=4466).
# - Annotation ID 4352 has a bbox out of image bounds (image_id=4467).
# - Annotation ID 4353 has a bbox out of image bounds (image_id=4468).
# - Annotation ID 4354 has a bbox out of image bounds (image_id=4469).
# - Annotation ID 4355 has a bbox out of image bounds (image_id=4470).
# - Annotation ID 4356 has a bbox out of image bounds (image_id=4471).
# - Annotation ID 4357 has a bbox out of image bounds (image_id=4472).
# - Annotation ID 4358 has a bbox out of image bounds (image_id=4473).
# - Annotation ID 4359 has a bbox out of image bounds (image_id=4474).
# - Annotation ID 4360 has a bbox out of image bounds (image_id=4475).
# - Annotation ID 4361 has a bbox out of image bounds (image_id=4476).
# - Annotation ID 4362 has a bbox out of image bounds (image_id=4477).
# - Annotation ID 4363 has a bbox out of image bounds (image_id=4478).
# - Annotation ID 4364 has a bbox out of image bounds (image_id=4479).
# - Annotation ID 4365 has a bbox out of image bounds (image_id=4480).
# - Annotation ID 4366 has a bbox out of image bounds (image_id=4481).
# ...
# - Annotation ID 111934 has a bbox out of image bounds (image_id=98962).
# - Annotation ID 111935 has a bbox out of image bounds (image_id=98963).
# - Annotation ID 111936 has a bbox out of image bounds (image_id=98964).
# - Annotation ID 111937 has a bbox out of image bounds (image_id=98965).
# - Annotation ID 111938 has a bbox out of image bounds (image_id=98966).
# - Annotation ID 111939 has a bbox out of image bounds (image_id=98967).
# - Annotation ID 111940 has a bbox out of image bounds (image_id=98968).
# - Annotation ID 111941 has a bbox out of image bounds (image_id=98969).
# - Annotation ID 111942 has a bbox out of image bounds (image_id=98970).
# - Annotation ID 111943 has a bbox out of image bounds (image_id=98971).
# - Annotation ID 111944 has a bbox out of image bounds (image_id=98972).
# - Annotation ID 111945 has a bbox out of image bounds (image_id=98973).
# - Annotation ID 111946 has a bbox out of image bounds (image_id=98974).
# - Annotation ID 111947 has a bbox out of image bounds (image_id=98975).
# - Annotation ID 111948 has a bbox out of image bounds (image_id=98976).
# - Annotation ID 111949 has a bbox out of image bounds (image_id=98977).
# - Annotation ID 111950 has a bbox out of image bounds (image_id=98978).
# - Annotation ID 111951 has a bbox out of image bounds (image_id=98979).
# - Annotation ID 111952 has a bbox out of image bounds (image_id=98980).
# - Annotation ID 111953 has a bbox out of image bounds (image_id=98981).
# - Annotation ID 111954 has a bbox out of image bounds (image_id=98982).
# - Annotation ID 111955 has a bbox out of image bounds (image_id=98983).
# - Annotation ID 111956 has a bbox out of image bounds (image_id=98984).
# - Annotation ID 111957 has a bbox out of image bounds (image_id=98985).
# - Annotation ID 111958 has a bbox out of image bounds (image_id=98986).
# - Annotation ID 111959 has a bbox out of image bounds (image_id=98987).
# - Annotation ID 111960 has a bbox out of image bounds (image_id=98988).
# - Annotation ID 111961 has a bbox out of image bounds (image_id=98989).
# - Annotation ID 111962 has a bbox out of image bounds (image_id=98990).
# - Annotation ID 111963 has a bbox out of image bounds (image_id=98991).
# - Annotation ID 111964 has a bbox out of image bounds (image_id=98992).
# - Annotation ID 111965 has a bbox out of image bounds (image_id=98993).
# - Annotation ID 111966 has a bbox out of image bounds (image_id=98994).
# - Annotation ID 111967 has a bbox out of image bounds (image_id=98995).
# - Annotation ID 111968 has a bbox out of image bounds (image_id=98996).
# - Annotation ID 111969 has a bbox out of image bounds (image_id=98997).
# - Annotation ID 111970 has a bbox out of image bounds (image_id=98998).
# - Annotation ID 111971 has a bbox out of image bounds (image_id=98999).
# - Annotation ID 111972 has a bbox out of image bounds (image_id=99000).
# - Annotation ID 111973 has a bbox out of image bounds (image_id=99001).
# - Annotation ID 111974 has a bbox out of image bounds (image_id=99002).
# - Annotation ID 111975 has a bbox out of image bounds (image_id=99003).
# - Annotation ID 111976 has a bbox out of image bounds (image_id=99004).
# - Annotation ID 111977 has a bbox out of image bounds (image_id=99005).
# - Annotation ID 111978 has a bbox out of image bounds (image_id=99006).
# - Annotation ID 111979 has a bbox out of image bounds (image_id=99007).
# - Annotation ID 111980 has a bbox out of image bounds (image_id=99008).
# - Annotation ID 111981 has a bbox out of image bounds (image_id=99009).
# - Annotation ID 111982 has a bbox out of image bounds (image_id=99010).
# - Annotation ID 111983 has a bbox out of image bounds (image_id=99011).
# - Annotation ID 111984 has a bbox out of image bounds (image_id=99012).
# - Annotation ID 111985 has a bbox out of image bounds (image_id=99013).
# - Annotation ID 111986 has a bbox out of image bounds (image_id=99014).
# - Annotation ID 111987 has a bbox out of image bounds (image_id=99015).
# - Annotation ID 111988 has a bbox out of image bounds (image_id=99016).
# - Annotation ID 111989 has a bbox out of image bounds (image_id=99017).
# - Annotation ID 111990 has a bbox out of image bounds (image_id=99018).
# - Annotation ID 111991 has a bbox out of image bounds (image_id=99019).
# - Annotation ID 111992 has a bbox out of image bounds (image_id=99020).
# - Annotation ID 111993 has a bbox out of image bounds (image_id=99021).
# - Annotation ID 111994 has a bbox out of image bounds (image_id=99022).
# - Annotation ID 111995 has a bbox out of image bounds (image_id=99023).
# - Annotation ID 111996 has a bbox out of image bounds (image_id=99024).
# - Annotation ID 111997 has a bbox out of image bounds (image_id=99025).
# - Annotation ID 111998 has a bbox out of image bounds (image_id=99026).
# - Annotation ID 111999 has a bbox out of image bounds (image_id=99027).
# - Annotation ID 112000 has a bbox out of image bounds (image_id=99028).
# - Annotation ID 112001 has a bbox out of image bounds (image_id=99029).
# - Annotation ID 112002 has a bbox out of image bounds (image_id=99030).
# - Annotation ID 112003 has a bbox out of image bounds (image_id=99031).
# - Annotation ID 112004 has a bbox out of image bounds (image_id=99032).
# - Annotation ID 112005 has a bbox out of image bounds (image_id=99033).
# - Annotation ID 112006 has a bbox out of image bounds (image_id=99034).
# - Annotation ID 112007 has a bbox out of image bounds (image_id=99035).
# - Annotation ID 112008 has a bbox out of image bounds (image_id=99036).
# - Annotation ID 112009 has a bbox out of image bounds (image_id=99037).
# - Annotation ID 112010 has a bbox out of image bounds (image_id=99038).
# - Annotation ID 112011 has a bbox out of image bounds (image_id=99039).
# - Annotation ID 112012 has a bbox out of image bounds (image_id=99040).
# - Annotation ID 112013 has a bbox out of image bounds (image_id=99041).
# - Annotation ID 112014 has a bbox out of image bounds (image_id=99042).
# - Annotation ID 112015 has a bbox out of image bounds (image_id=99043).
# - Annotation ID 112016 has a bbox out of image bounds (image_id=99044).
# - Annotation ID 112017 has a bbox out of image bounds (image_id=99045).
# - Annotation ID 112018 has a bbox out of image bounds (image_id=99046).
# - Annotation ID 112019 has a bbox out of image bounds (image_id=99047).
# - Annotation ID 112020 has a bbox out of image bounds (image_id=99048).
# - Annotation ID 112021 has a bbox out of image bounds (image_id=99049).
# - Annotation ID 112022 has a bbox out of image bounds (image_id=99050).
# - Annotation ID 112023 has a bbox out of image bounds (image_id=99051).
# - Annotation ID 112024 has a bbox out of image bounds (image_id=99052).
# - Annotation ID 112025 has a bbox out of image bounds (image_id=99053).
# - Annotation ID 112026 has a bbox out of image bounds (image_id=99054).
# - Annotation ID 112027 has a bbox out of image bounds (image_id=99055).
# - Annotation ID 112028 has a bbox out of image bounds (image_id=99056).
# - Annotation ID 112029 has a bbox out of image bounds (image_id=99057).
# - Annotation ID 112030 has a bbox out of image bounds (image_id=99058).
# - Annotation ID 112031 has a bbox out of image bounds (image_id=99059).
# - Annotation ID 112032 has a bbox out of image bounds (image_id=99060).
# - Annotation ID 112033 has a bbox out of image bounds (image_id=99061).
# - Annotation ID 112034 has a bbox out of image bounds (image_id=99062).
# - Annotation ID 112035 has a bbox out of image bounds (image_id=99063).
# - Annotation ID 112036 has a bbox out of image bounds (image_id=99064).
# - Annotation ID 112037 has a bbox out of image bounds (image_id=99065).
# - Annotation ID 112038 has a bbox out of image bounds (image_id=99066).
# - Annotation ID 112039 has a bbox out of image bounds (image_id=99067).
# - Annotation ID 112040 has a bbox out of image bounds (image_id=99068).
# - Annotation ID 112041 has a bbox out of image bounds (image_id=99069).
# - Annotation ID 112042 has a bbox out of image bounds (image_id=99070).
# - Annotation ID 112043 has a bbox out of image bounds (image_id=99071).
# - Annotation ID 112044 has a bbox out of image bounds (image_id=99072).
# - Annotation ID 112045 has a bbox out of image bounds (image_id=99073).
# - Annotation ID 112046 has a bbox out of image bounds (image_id=99074).
# - Annotation ID 112047 has a bbox out of image bounds (image_id=99075).
# - Annotation ID 112048 has a bbox out of image bounds (image_id=99076).
# - Annotation ID 112049 has a bbox out of image bounds (image_id=99077).
# - Annotation ID 112050 has a bbox out of image bounds (image_id=99078).
# - Annotation ID 112051 has a bbox out of image bounds (image_id=99079).
# - Annotation ID 112052 has a bbox out of image bounds (image_id=99080).
# - Annotation ID 112053 has a bbox out of image bounds (image_id=99081).
# - Annotation ID 112054 has a bbox out of image bounds (image_id=99082).
# - Annotation ID 112055 has a bbox out of image bounds (image_id=99083).
# - Annotation ID 112068 has a bbox out of image bounds (image_id=99096).
# - Annotation ID 112069 has a bbox out of image bounds (image_id=99097).
# - Annotation ID 112070 has a bbox out of image bounds (image_id=99098).
# - Annotation ID 112071 has a bbox out of image bounds (image_id=99099).
# - Annotation ID 112072 has a bbox out of image bounds (image_id=99100).
# - Annotation ID 112073 has a bbox out of image bounds (image_id=99101).
# - Annotation ID 112074 has a bbox out of image bounds (image_id=99102).
# - Annotation ID 112075 has a bbox out of image bounds (image_id=99103).
# - Annotation ID 112076 has a bbox out of image bounds (image_id=99104).
# - Annotation ID 112077 has a bbox out of image bounds (image_id=99105).
# - Annotation ID 112078 has a bbox out of image bounds (image_id=99106).
# - Annotation ID 112079 has a bbox out of image bounds (image_id=99107).
# - Annotation ID 112080 has a bbox out of image bounds (image_id=99108).
# - Annotation ID 112081 has a bbox out of image bounds (image_id=99109).
# - Annotation ID 112082 has a bbox out of image bounds (image_id=99110).
# - Annotation ID 112083 has a bbox out of image bounds (image_id=99111).
# - Annotation ID 112084 has a bbox out of image bounds (image_id=99112).
# - Annotation ID 112085 has a bbox out of image bounds (image_id=99113).
# - Annotation ID 112086 has a bbox out of image bounds (image_id=99114).
# - Annotation ID 112087 has a bbox out of image bounds (image_id=99115).
# - Annotation ID 112088 has a bbox out of image bounds (image_id=99116).
# - Annotation ID 112089 has a bbox out of image bounds (image_id=99117).
# - Annotation ID 112090 has a bbox out of image bounds (image_id=99118).
# - Annotation ID 112091 has a bbox out of image bounds (image_id=99119).
# - Annotation ID 112092 has a bbox out of image bounds (image_id=99120).
# - Annotation ID 112093 has a bbox out of image bounds (image_id=99121).
# - Annotation ID 112094 has a bbox out of image bounds (image_id=99122).
# - Annotation ID 112095 has a bbox out of image bounds (image_id=99123).
# - Annotation ID 112096 has a bbox out of image bounds (image_id=99124).
# - Annotation ID 112097 has a bbox out of image bounds (image_id=99125).
# - Annotation ID 112098 has a bbox out of image bounds (image_id=99126).
# - Annotation ID 112099 has a bbox out of image bounds (image_id=99127).
# - Annotation ID 112100 has a bbox out of image bounds (image_id=99128).
# - Annotation ID 112101 has a bbox out of image bounds (image_id=99129).
# - Annotation ID 112102 has a bbox out of image bounds (image_id=99130).
# - Annotation ID 112103 has a bbox out of image bounds (image_id=99131).
# - Annotation ID 112104 has a bbox out of image bounds (image_id=99132).
# - Annotation ID 112105 has a bbox out of image bounds (image_id=99133).
# - Annotation ID 112106 has a bbox out of image bounds (image_id=99134).
# - Annotation ID 112107 has a bbox out of image bounds (image_id=99135).
# - Annotation ID 112108 has a bbox out of image bounds (image_id=99136).
# - Annotation ID 112109 has a bbox out of image bounds (image_id=99137).
# - Annotation ID 112110 has a bbox out of image bounds (image_id=99138).
# - Annotation ID 112111 has a bbox out of image bounds (image_id=99139).
# - Annotation ID 112112 has a bbox out of image bounds (image_id=99140).
# - Annotation ID 112113 has a bbox out of image bounds (image_id=99141).
# - Annotation ID 112114 has a bbox out of image bounds (image_id=99142).
# - Annotation ID 112115 has a bbox out of image bounds (image_id=99143).
# - Annotation ID 112116 has a bbox out of image bounds (image_id=99144).
# - Annotation ID 112117 has a bbox out of image bounds (image_id=99145).
# - Annotation ID 112118 has a bbox out of image bounds (image_id=99146).
# - Annotation ID 112119 has a bbox out of image bounds (image_id=99147).
# - Annotation ID 112120 has a bbox out of image bounds (image_id=99148).
# - Annotation ID 112121 has a bbox out of image bounds (image_id=99149).
# - Annotation ID 112122 has a bbox out of image bounds (image_id=99150).
# - Annotation ID 112123 has a bbox out of image bounds (image_id=99151).
# - Annotation ID 112124 has a bbox out of image bounds (image_id=99152).
# - Annotation ID 112125 has a bbox out of image bounds (image_id=99153).
# - Annotation ID 112126 has a bbox out of image bounds (image_id=99154).
# - Annotation ID 112127 has a bbox out of image bounds (image_id=99155).
# - Annotation ID 112128 has a bbox out of image bounds (image_id=99156).
# - Annotation ID 112129 has a bbox out of image bounds (image_id=99157).
# - Annotation ID 112130 has a bbox out of image bounds (image_id=99158).
# - Annotation ID 112131 has a bbox out of image bounds (image_id=99159).
# - Annotation ID 112132 has a bbox out of image bounds (image_id=99160).
# - Annotation ID 112133 has a bbox out of image bounds (image_id=99161).
# - Annotation ID 112134 has a bbox out of image bounds (image_id=99162).
# - Annotation ID 112144 has a bbox out of image bounds (image_id=99172).
# - Annotation ID 112204 has a bbox out of image bounds (image_id=99232).
# - Annotation ID 112205 has a bbox out of image bounds (image_id=99233).
# - Annotation ID 112206 has a bbox out of image bounds (image_id=99234).
# - Annotation ID 112207 has a bbox out of image bounds (image_id=99235).
# - Annotation ID 112208 has a bbox out of image bounds (image_id=99236).
# - Annotation ID 112209 has a bbox out of image bounds (image_id=99237).
# - Annotation ID 112210 has a bbox out of image bounds (image_id=99238).
# - Annotation ID 112211 has a bbox out of image bounds (image_id=99239).
# - Annotation ID 112212 has a bbox out of image bounds (image_id=99240).
# - Annotation ID 112213 has a bbox out of image bounds (image_id=99241).
# - Annotation ID 112214 has a bbox out of image bounds (image_id=99242).
# - Annotation ID 112215 has a bbox out of image bounds (image_id=99243).
# - Annotation ID 112216 has a bbox out of image bounds (image_id=99244).
# - Annotation ID 112217 has a bbox out of image bounds (image_id=99245).
# - Annotation ID 112218 has a bbox out of image bounds (image_id=99246).
# - Annotation ID 112478 has a bbox out of image bounds (image_id=99506).
# - Annotation ID 112479 has a bbox out of image bounds (image_id=99507).
# - Annotation ID 112480 has a bbox out of image bounds (image_id=99508).
# - Annotation ID 112481 has a bbox out of image bounds (image_id=99509).
# - Annotation ID 112482 has a bbox out of image bounds (image_id=99510).
# - Annotation ID 112483 has a bbox out of image bounds (image_id=99511).
# - Annotation ID 112484 has a bbox out of image bounds (image_id=99512).
# - Annotation ID 112485 has a bbox out of image bounds (image_id=99513).
# - Annotation ID 112486 has a bbox out of image bounds (image_id=99514).
# - Annotation ID 112487 has a bbox out of image bounds (image_id=99515).
# - Annotation ID 117857 has a bbox out of image bounds (image_id=105003).
# - Annotation ID 117858 has a bbox out of image bounds (image_id=105004).
# - Annotation ID 117859 has a bbox out of image bounds (image_id=105005).
# - Annotation ID 117866 has a bbox out of image bounds (image_id=105027).
# - Annotation ID 117867 has a bbox out of image bounds (image_id=105028).
# - Annotation ID 118913 has a bbox out of image bounds (image_id=106112).
#
# Total Issues: 9747
#
# Dataset validation failed. See issues above.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.63 🚀 Python-3.10.16 torch-2.5.1 CPU (Apple M3)
# Setup complete ✅ (8 CPUs, 16.0 GB RAM, 129.5/460.4 GB disk)

# %%
model = YOLO('yolo11n.pt')  # 'n' denotes the nano version

# %%
model.device
# Out:
# device(type='cpu')

# %%
model.train(
    data='dataset.yaml',  # Path to the dataset configuration file
    epochs=50,            # Number of training epochs
    imgsz=640,            # Image size for training
    batch=16,             # Batch size (adjust based on your hardware capabilities)
    name='drone_vs_bird_finetune',  # Name of the training run
    pretrained=True,      # Use pre-trained weights
    device='cpu',         # GPU device index (set to 'cpu' on mac, GPU acceration is only for CUDA)
    amp=True              # Enable Automatic Mixed Precision (for faster training)   
)
# Out:
# Ultralytics 8.3.63 🚀 Python-3.10.16 torch-2.5.1 CPU (Apple M3)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=dataset.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=drone_vs_bird_finetune4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/drone_vs_bird_finetune4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Scanning /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/train... 0 images, 74526 backgrounds, 0 corrupt: 100%|██████████| 74526/74526 [00:05<00:00, 13071.71it/s]
# train: WARNING ⚠️ No labels found in /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/train.cache. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# train: New cache created: /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/train.cache
# WARNING ⚠️ No labels found in /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/train.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# val: Scanning /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/val... 0 images, 15970 backgrounds, 0 corrupt: 100%|██████████| 15970/15970 [00:01<00:00, 13133.95it/s]
# val: WARNING ⚠️ No labels found in /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/val.cache. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# val: New cache created: /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/val.cache
# WARNING ⚠️ No labels found in /Users/aditya/Documents/Github/drone-vs-bird-challenge/dataset/labels/val.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# Plotting labels to runs/detect/drone_vs_bird_finetune4/labels.jpg...
# zero-size array to reduction operation maximum which has no identity
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/drone_vs_bird_finetune4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G          0      125.8          0          0        640:   1%|          | 34/4658 [03:48<8:38:22,  6.73s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.train(
#       2     data='dataset.yaml',  # Path to the dataset configuration file
#       3     epochs=50,            # Number of training epochs
#       4     imgsz=640,            # Image size for training
#       5     batch=16,             # Batch size (adjust based on your hardware capabilities)
#       6     name='drone_vs_bird_finetune',  # Name of the training run
#       7     pretrained=True,      # Use pre-trained weights
#       8     device='cpu',         # GPU device index (set to 'cpu' on mac, GPU acceration is only for CUDA)
#       9     amp=True              # Enable Automatic Mixed Precision (for faster training)
#      10 )
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/ultralytics/engine/model.py:806, in Model.train(self, trainer, **kwargs)
#     803     self.model = self.trainer.model
#     805 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 806 self.trainer.train()
#     807 # Update model and cfg after training
#     808 if RANK in {-1, 0}:
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/ultralytics/engine/trainer.py:207, in BaseTrainer.train(self)
#     204         ddp_cleanup(self, str(file))
#     206 else:
# --> 207     self._do_train(world_size)
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/ultralytics/engine/trainer.py:389, in BaseTrainer._do_train(self, world_size)
#     384     self.tloss = (
#     385         (self.tloss * i + self.loss_items) / (i + 1) if self.tloss is not None else self.loss_items
#     386     )
#     388 # Backward
# --> 389 self.scaler.scale(self.loss).backward()
#     391 # Optimize - https://pytorch.org/docs/master/notes/amp_examples.html
#     392 if ni - last_opt_step >= self.accumulate:
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/.pyenv/versions/3.10.16/lib/python3.10/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# Ultralytics 8.3.63 🚀 Python-3.10.16 torch-2.5.1 CPU (Apple M3)
# [34m[1mengine/trainer: [0mtask=detect, mode=train, model=yolo11n.pt, data=dataset.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=drone_vs_bird_finetune, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/drone_vs_bird_finetune
